# %%
p=1000
d=0.2
fp=p-(p*d)
print("FINAL PRICE AFTER DISCOUNT:",fp)
# Out:
# FINAL PRICE AFTER DISCOUNT: 800.0

# %%
p=1000
d=0.2
fp=p-(p*d)
tax=fp*0.12
add=tax+fp
print("FINAL PRICE AFTER DISCOUNT:",fp)
print(f"CUSTOMER NEEDS TO PAY {add} after discount and tax")
# Out:
# FINAL PRICE AFTER DISCOUNT: 800.0
# CUSTOMER NEEDS TO PAY 896.0 after discount and tax

# %%
customer_n="PRACHI_19"
age=19
salary=55000.75
print(type(customer_n))
print(type(age))
print(type(salary))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
marks=int(input("Enter the score:"))
if marks>95:
    print("GRADE: A+(OUTSTANDING)")
elif marks>90:
    print("GRADE: A(Excellent)")
elif marks>75:
  print("GRADE: B(Good)")
elif marks>60:
  print("GRADE: C(NEEDS IMPROVEMENT)")
else:
  print("GRADE: D(FAIL)")
# Out:
# Enter the score:78
# GRADE: B(Good)

# %%
customers=["PRACHI","GOURI","ASMITA","PRIYAL","DIVYA",25]
for name in customers:
  print("SENDING EMAIL TO:",name)
# Out:
# SENDING EMAIL TO: PRACHI
# SENDING EMAIL TO: GOURI
# SENDING EMAIL TO: ASMITA
# SENDING EMAIL TO: PRIYAL
# SENDING EMAIL TO: DIVYA
# SENDING EMAIL TO: 25

# %%
student={"PRACHI":85,"GOURI":92,"DIVYA":74}
for name, marks in student.items():
  if marks > 90:
    grade="A"
  elif marks >=75:
    grade="B"
  else:
    grade="C"
  print(f"STUDENT:{name},MARKS:{marks},GRADE:{grade}")
# Out:
# STUDENT:PRACHI,MARKS:85,GRADE:B
# STUDENT:GOURI,MARKS:92,GRADE:A
# STUDENT:DIVYA,MARKS:74,GRADE:C

# %%
def greet(name):
  print("HELLO", name,"WELCOME TO THE BOOTCAMP!!")
greet("PRACH")
greet("DIVYAA")
# Out:
# HELLO PRACH WELCOME TO THE BOOTCAMP!!
# HELLO DIVYAA WELCOME TO THE BOOTCAMP!!

# %%
def Money(x,y):
  total=x+y
  return total
Money(1000,2000)
Money("abc","xyz")
# Out:
# 'abcxyz'

# %%
def eligibility(age):
  print(age)
  if age>=18:
    print("ELIGIBLE FOR VOTING")
  else:
    print("NOT ELIGIBLE FOR VOTING")
eligibility(19)
eligibility(17)
# Out:
# 19
# ELIGIBLE FOR VOTING
# 17
# NOT ELIGIBLE FOR VOTING

# %%
#hw
def calculate_discount(price, discount_percent):
  return price - (price * discount_percent / 100)
def apply_tax(price, tax_percent):
 return price + (price * tax_percent / 100)
price = 1000
discounted_price = calculate_discount (price, 10)
final_price = apply_tax(discounted_price, 18)
print ("Final Price after discount and tax:", final_price)
# Out:
# Final Price after discount and tax: 1062.0

# %%
import math
print("SQUARE ROOT OF 25:",math.sqrt(25))
print("VALUE OF PI:",math.pi)
# Out:
# SQUARE ROOT OF 25: 5.0
# VALUE OF PI: 3.141592653589793

# %%
def issue_books(student_name, books):
  print (f"\n (student_name) borrowed: ")
  for book in books:
   print ("-", book)
def calculate_fine(days_late):
 fine_per_day = 5
 return days_late*fine_per_day
def student_report(student_name, books, days_late):
 issue_books(student_name, books)
 fine=calculate_fine(days_late)
 print(f"Fine to be paid:{fine}\n")
student_report("Rahul", ["Python Basics", "Data Science 101"], 3)
student_report("Priya", ["MACHINE LEARNING"], 0)
# Out:
#  (student_name) borrowed:
# - Python Basics
# - Data Science 101
# Fine to be paid:15
#
#
#  (student_name) borrowed:
# - MACHINE LEARNING
# Fine to be paid:0

# %%
nums = [1,2,3]
print(nums)
mixed = [1,"a",True,3.14]
print(mixed)
nested = [[1,2], [3,4]]
print(nested)
empty = list()
print(empty)
a = [10, 20, 30, 40, 50]
a [0]
a[-1]
a [1:4]
a[: :2]
a[::-1]
# Out:
# [1, 2, 3]
# [1, 'a', True, 3.14]
# [[1, 2], [3, 4]]
# []
# [50, 40, 30, 20, 10]

# %%
a = [10, 20, 30, 40, 50]

# %%
a.append (60)
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a.insert(1,15)
print(a)
# Out:
# [10, 15, 20, 30, 40, 50, 60]

# %%
a.remove (30)
print(a)
# Out:
# [10, 15, 20, 40, 50, 60]

# %%
id =a.index(40)
print(a)
# Out:
# [10, 15, 20, 40, 50, 60]

# %%
count=a.count (20)
print(a)
# Out:
# [10, 15, 20, 40, 50, 60]

# %%
a.sort()
print(a)
# Out:
# [10, 15, 20, 40, 50, 60]

# %%
b=sorted(a,reverse=True)
print(a)
# Out:
# [10, 15, 20, 40, 50, 60]

# %%
a.reverse()
print(a)
# Out:
# [60, 50, 40, 20, 15, 10]

# %%
squares=[x*x for x in range(6)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
events=[x for x in range(10) if x%2==0]
print(events)
# Out:
# [0, 2, 4, 6, 8]

# %%
pairs=[(i,j)for i in range(2) for j in range(2)]
print(pairs)
# Out:
# [(0, 0), (0, 1), (1, 0), (1, 1)]

# %%
marks=[78,85,92,67,88]

# %%
marks.remove(min(marks))
print(marks)
# Out:
# [78, 85, 92, 88]

# %%
marks.append(90)
print(marks)
# Out:
# [78, 85, 92, 88, 90]

# %%
marks.sort(reverse=True)
print(marks)
# Out:
# [92, 90, 88, 85, 78]

# %%
top_3=marks[:3]
print(marks)
# Out:
# [92, 90, 88, 85, 78]

# %%
average_top3=sum(top_3)/len(top_3)
print(marks)
# Out:
# [92, 90, 88, 85, 78]

# %%
t=(1,2,3)
single=(42)
packed = 1,2,3

# %%
x,y,z=t
a,*mid,b=(1,2,3,4,5)
print(t)
print(a)
print(mid)
print(b)
# Out:
# (1, 2, 3)
# 1
# [2, 3, 4]
# 5

# %%
emp = {"id":101,"name":"Asha","dept":"HR"}

# %%
alt = dict(id=101, name="Asha", dept="HR")

# %%
empty ={}

# %%
emp["name"]
# Out:
# 'Asha'

# %%
emp.get("email")

# %%
emp.get("email", "")
# Out:
# ''

# %%
emp["salary"]=70000

# %%
emp.update({"dept": "HR Analytics","level":"senior"})

# %%
emp.pop("level")
# Out:
# 'senior'

# %%
emp.pop("x", None)

# %%
emp.popitem()
# Out:
# ('salary', 70000)

# %%
del emp["dept"]

# %%
for k in emp:
 print(k)
for k, v in emp.items():
 print(k, v)
for v in emp. values():
 print(v)
prefs ={}
prefs.setdefault("theme", "light")
# Out:
# id
# name
# id 101
# name Asha
# 101
# Asha
# 'light'

# %%
text ="mississippi"
counts ={}
for ch in text:
 counts[ch]=counts.get(ch,0)+1
print(counts)
# Out:
# {'m': 1, 'i': 4, 's': 4, 'p': 2}

# %%
person={"name":"Asha","addr":{"city":"Pune","pin":411001}}
city=person.get("addr",{}).get("city")
print(city)
# Out:
# Pune

# %%
fruits={"apple","banana","cherry","apple"}
print(fruits)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
set1={1,2,3,4}
sets2={3,4,5,6}
set1.add(10)
set1.discard(2)
print("Union:",set1|sets2)
print("Intersection:",set1&sets2)
print("Difference:",set1-sets2)
print("Is Subset?", {3,4}.issubset(set1))
# Out:
# Union: {1, 3, 4, 5, 6, 10}
# Intersection: {3, 4}
# Difference: {1, 10}
# Is Subset? True

# %%
import pandas as pd
import numpy as np
data={'Name':['Alice','Bob','David','Prachi'],
      'Age':[25,np.nan,30,np.nan],
      'Salary':[50000,60000,None,45000]
      }
df=pd.DataFrame(data)
print("Before cleaning:")
print(df)
a="********************"
print(a)
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Salary'].fillna(df['Salary'].median(),inplace=True)
print("After cleaning:")
print(df)
# Out:
# Before cleaning:
#      Name   Age   Salary
# 0   Alice  25.0  50000.0
# 1     Bob   NaN  60000.0
# 2   David  30.0      NaN
# 3  Prachi   NaN  45000.0
# ********************
# After cleaning:
#      Name   Age   Salary
# 0   Alice  25.0  50000.0
# 1     Bob  27.5  60000.0
# 2   David  30.0  50000.0
# 3  Prachi  27.5  45000.0
# /tmp/ipykernel_567/3516525188.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
# /tmp/ipykernel_567/3516525188.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].median(),inplace=True)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=[10,12,13,12,11,200,14,13,15,12]
sns.boxplot(data)
plt.show()
Q1,Q3=np.percentile(data,[25,75])
IQR=Q3-Q1
lower,upper=Q1-1.5*IQR,Q3+1.5*IQR
outliers=[x for x in data if x<lower or x>upper]
print("Outliers detected:",outliers)
# Out:
# Outliers detected: [200]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd
df=pd.DataFrame({'AGE':[18,22,30,40],
                 'SALARY':[20000,50000,80000,120000]})
scaler=MinMaxScaler()
df_norm=scaler.fit_transform(df)
scaler_std=StandardScaler()
df_std=scaler_std.fit_transform(df)
print("Original Data:\n",df)
print("\nNormalized:\n",df_norm)
print("\nStandardized:\n",df_std)
# Out:
# Original Data:
#     AGE  SALARY
# 0   18   20000
# 1   22   50000
# 2   30   80000
# 3   40  120000
#
# Normalized:
#  [[0.         0.        ]
#  [0.18181818 0.3       ]
#  [0.54545455 0.6       ]
#  [1.         1.        ]]
#
# Standardized:
#  [[-1.12943277 -1.28390102]
#  [-0.65388213 -0.47301616]
#  [ 0.29721915  0.33786869]
#  [ 1.48609575  1.41904849]]

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
f=pd.DataFrame({
'Name':['Alice','Bob','Charlie'],
'Age':[25,32,47],
'Country':['US','India','US'],
'Spend1':[200,150,300],
'Spend2':[100,200,400]
})
f['Total_Spend']=f['Spend1']+f['Spend2']
f['Age_Group']=pd.cut(f['Age'],bins=[0,30,50],labels=['Young','Middle'])
encoder= LabelEncoder()
f['Country_Code']=encoder.fit_transform(f['Country'])
print(f)
# Out:
#       Name  Age Country  Spend1  Spend2  Total_Spend Age_Group  Country_Code
# 0    Alice   25      US     200     100          300     Young             1
# 1      Bob   32   India     150     200          350    Middle             0
# 2  Charlie   47      US     300     400          700    Middle             1

# %%
import pandas as pd
df=pd.read_csv("/content/students.csv")
print(df.head())
print(df.info())
print(df.describe())
print(df.isnull().sum())
print(df)
# Out:
#    Gender Parental_Education  Math_Score  Reading_Score  Writing_Score  \
# 0    Male             Master        84.0           89.0           69.0
# 1  Female                PhD        65.0           63.0           47.0
# 2    Male             Master        66.0           42.0           80.0
# 3    Male                PhD        43.0           67.0           90.0
# 4    Male                PhD        56.0           41.0           52.0
#
#    Attendance
# 0        56.0
# 1        79.0
# 2        80.0
# 3        94.0
# 4        95.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              10000 non-null  object
#  1   Parental_Education  10000 non-null  object
#  2   Math_Score          9500 non-null   float64
#  3   Reading_Score       9500 non-null   float64
#  4   Writing_Score       9500 non-null   float64
#  5   Attendance          9500 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 468.9+ KB
# None
#         Math_Score  Reading_Score  Writing_Score   Attendance
# count  9500.000000    9500.000000    9500.000000  9500.000000
# mean     64.445158      64.238211      64.572632    74.359474
# std      20.179436      20.079068      20.397577    14.395287
# min      30.000000      30.000000      30.000000    50.000000
# 25%      47.000000      47.000000      47.000000    62.000000
# 50%      65.000000      64.000000      65.000000    74.000000
# 75%      82.000000      82.000000      83.000000    87.000000
# max      99.000000      99.000000      99.000000    99.000000
# Gender                  0
# Parental_Education      0
# Math_Score            500
# Reading_Score         500
# Writing_Score         500
# Attendance            500
# dtype: int64
#       Gender Parental_Education  Math_Score  Reading_Score  Writing_Score  \
# 0       Male             Master        84.0           89.0           69.0
# 1     Female                PhD        65.0           63.0           47.0
# 2       Male             Master        66.0           42.0           80.0
# 3       Male                PhD        43.0           67.0           90.0
# 4       Male                PhD        56.0           41.0           52.0
# ...      ...                ...         ...            ...            ...
# 9995  Female        High School        49.0           52.0           65.0
# 9996    Male        High School        47.0           74.0           86.0
# 9997  Female        High School        83.0           56.0           66.0
# 9998  Female                PhD        41.0           85.0           81.0
# 9999    Male             Master        54.0           88.0           92.0
#
#       Attendance
# 0           56.0
# 1           79.0
# 2           80.0
# 3           94.0
# 4           95.0
# ...          ...
# 9995        70.0
# 9996        55.0
# 9997        94.0
# 9998        99.0
# 9999        84.0
#
# [10000 rows x 6 columns]

# %%
df['Total_Score'] = df['Math_Score'] + df['Reading_Score'] + df['Writing_Score']
df['Average_Score'] = df['Total_Score'] / 3
print(df.head())
# Out:
#    Gender Parental_Education  Math_Score  Reading_Score  Writing_Score  \
# 0    Male             Master        84.0           89.0           69.0
# 1  Female                PhD        65.0           63.0           47.0
# 2    Male             Master        66.0           42.0           80.0
# 3    Male                PhD        43.0           67.0           90.0
# 4    Male                PhD        56.0           41.0           52.0
#
#    Attendance  Total_Score  Average_Score
# 0        56.0        242.0      80.666667
# 1        79.0        175.0      58.333333
# 2        80.0        188.0      62.666667
# 3        94.0        200.0      66.666667
# 4        95.0        149.0      49.666667

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df= pd.read_csv("/content/tips_dataset_350 (3).csv")

# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df= pd.read_csv("/content/tips_dataset_350 (3).csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day  size
# 0       33.32  5.37    Male     No  Sun     3
# 1       49.05  7.45  Female     No  Sun     2
# 2       23.72  4.16  Female     No  Sun     2
# 3       54.55  4.46  Female    Yes  Sun     2
# 4       59.45  5.92    Male    Yes  Sun     2

# %%
sns.histplot(df["total_bill"],kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(x=df["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.countplot(x="day",data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.scatterplot(x="total_bill",y="tip" , data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(x="smoker",y="tip" ,data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
pd.crosstab(df["sex"], df["smoker"])
sns.heatmap(pd.crosstab(df["sex"],df["smoker"]),annot=True, cmap="YlGnBu")
# Out:
# <Axes: xlabel='smoker', ylabel='sex'>

# %%
sns.pairplot(df[["total_bill", "tip","size"]])

# %%
sns.boxplot(x="day",y="total_bill",hue="sex",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
plt.plot(df["total_bill"])
plt.title("Line PLot of total bills")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(df["day"].value_counts().index, df["day"].value_counts().values)
plt.show()

# %%
df["day"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
print(df["total_bill"].describe())
print("Skewness:", df["total_bill"].skew())
print("Kurtosis:", df["total_bill"].kurt())
# Out:
# count    350.000000
# mean      34.423371
# std       14.853806
# min        5.280000
# 25%       23.540000
# 50%       35.085000
# 75%       45.562500
# max       59.450000
# Name: total_bill, dtype: float64
# Skewness: -0.08160001775878163
# Kurtosis: -0.7842570419103381

# %%
print(df.corr(numeric_only=True))
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.872761  0.066696
# tip           0.872761  1.000000  0.065332
# size          0.066696  0.065332  1.000000

# %%
import statsmodels. api as sm
x =df["total_bill"]
y=df["tip"]
x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     1112.
# Date:                Sun, 08 Mar 2026   Prob (F-statistic):          2.02e-110
# Time:                        10:15:11   Log-Likelihood:                -524.45
# No. Observations:                 350   AIC:                             1053.
# Df Residuals:                     348   BIC:                             1061.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0304      0.147     -0.208      0.836      -0.319       0.258
# total_bill     0.1305      0.004     33.353      0.000       0.123       0.138
# ==============================================================================
# Omnibus:                        1.431   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.489   Jarque-Bera (JB):                1.334
# Skew:                           0.022   Prob(JB):                        0.513
# Kurtosis:                       2.701   Cond. No.                         94.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
